# %%
import pandas as pd

# %%
df = pd.DataFrame({"A": pd.arrays.SparseArray([0, 1, 0])})

# %%
df = pd.DataFrame({
    'users': clic_sales['user_id'],
    'items': clic_sales['sale_id']
})

# create pivot table
sparse_matrix = pd.pivot_table(
    df,
    values='items',
    index='users',
    columns='items',
    aggfunc=lambda x: 1,
    fill_value=0
)

# %%
df.sparse.to_dense()
# Out:
#    A
# 0  0
# 1  1
# 2  0

# %%
clic_sales = pd.read_csv('user_events__click_sale-2023.csv')

# %%
sparse_matrix
# Out:
# items                         00b6a124467e40e7b7f6a475d  \
# users
# 0005QevmiHglxrTLxqaQi4Wwasb2                          0
# 000kmsl9FuXfaI8CbVrSJywBaR83                          0
# 0039zvxsTycKfq4uKf5C32uS7dh1                          0
# 003IUnRedNW8JKjJZgPNm4CvTOk1                          0
# 003ZUZJNhXcX0G9TcAhp2gOJkPo1                          0
# ...                                                 ...
# zzvwHv6RsjRmZwe2oVHUUdJDY863                          0
# zzwW6RpigNg2a3Bzw1pUpTBPz1u1                          0
# zzx4PbLBmMXrNKVO2tQJNLAYj0x2                          0
# zzybu99VljYerdULrBYVVFBJ1zG3                          0
# zzyucfQBk5d7meVYkwDnm6B0iXQ2                          0
#
# items                         011ee106c69044cda86371d4c  \
# users
# 0005QevmiHglxrTLxqaQi4Wwasb2                          0
# 000kmsl9FuXfaI8CbVrSJywBaR83                          0
# 0039zvxsTycKfq4uKf5C32uS7dh1                          0
# ...
